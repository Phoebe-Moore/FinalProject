# %%
import pandas as pd
from scipy import stats

# %%
redwine = pd.read_csv ("/Users/zoe/Desktop/Final Project /Please work Red1.csv")

# %%
redwine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
redwine_crosstab = pd.crosstab(redwine["residual sugar"], redwine["quality"])

# %%
stats.chi2_contingency(redwine_crosstab)
# Out:
# (864.7915037110228,
#  1.6488532980084574e-28,
#  450,
#  array([[1.25078174e-02, 6.62914321e-02, 8.51782364e-01, 7.97998749e-01,
#          2.48905566e-01, 2.25140713e-02],
#         [5.00312695e-02, 2.65165729e-01, 3.40712946e+00, 3.19199500e+00,
#          9.95622264e-01, 9.00562852e-02],
#         [3.12695435e-02, 1.65728580e-01, 2.12945591e+00, 1.99499687e+00,
#          6.22263915e-01, 5.62851782e-02],
#         [2.18886804e-01, 1.16010006e+00, 1.49061914e+01, 1.39649781e+01,
#          4.35584740e+00, 3.93996248e-01],
#         [1.87617261e-01, 9.94371482e-01, 1.27767355e+01, 1.19699812e+01,
#          3.73358349e+00, 3.37711069e-01],
#         [3.62726704e-01, 1.92245153e+00, 2.47016886e+01, 2.31419637e+01,
#          7.21826141e+00, 6.52908068e-01],
#         [1.25078174e-02, 6.62914321e-02, 8.51782364e-01, 7.97998749e-01,
#          2.48905566e-01, 2.25140713e-02],
#         [4.75297061e-01, 2.51907442e+00, 3.23677298e+01, 3.03239525e+01,
# ...

# %%
redwine_crosstab = pd.crosstab(redwine["fixed acidity"], redwine["quality"])

# %%
stats.chi2_contingency(redwine_crosstab)
# Out:
# (736.0798648275643,
#  1.4159021578050688e-13,
#  475,
#  array([[6.25390869e-03, 3.31457161e-02, 4.25891182e-01, 3.98999375e-01,
#          1.24452783e-01, 1.12570356e-02],
#         [6.25390869e-03, 3.31457161e-02, 4.25891182e-01, 3.98999375e-01,
#          1.24452783e-01, 1.12570356e-02],
#         [6.25390869e-03, 3.31457161e-02, 4.25891182e-01, 3.98999375e-01,
#          1.24452783e-01, 1.12570356e-02],
#         [3.75234522e-02, 1.98874296e-01, 2.55534709e+00, 2.39399625e+00,
#          7.46716698e-01, 6.75422139e-02],
#         [2.50156348e-02, 1.32582864e-01, 1.70356473e+00, 1.59599750e+00,
#          4.97811132e-01, 4.50281426e-02],
#         [3.75234522e-02, 1.98874296e-01, 2.55534709e+00, 2.39399625e+00,
#          7.46716698e-01, 6.75422139e-02],
#         [2.50156348e-02, 1.32582864e-01, 1.70356473e+00, 1.59599750e+00,
#          4.97811132e-01, 4.50281426e-02],
#         [3.12695435e-02, 1.65728580e-01, 2.12945591e+00, 1.99499687e+00,
# ...

# %%
redwine_crosstab = pd.crosstab(redwine["volatile acidity"], redwine["quality"])

# %%
stats.chi2_contingency(redwine_crosstab)
# Out:
# (1589.2143598570324,
#  3.4291008970834183e-69,
#  710,
#  array([[1.87617261e-02, 9.94371482e-02, 1.27767355e+00, 1.19699812e+00,
#          3.73358349e-01, 3.37711069e-02],
#         [1.25078174e-02, 6.62914321e-02, 8.51782364e-01, 7.97998749e-01,
#          2.48905566e-01, 2.25140713e-02],
#         [6.25390869e-02, 3.31457161e-01, 4.25891182e+00, 3.98999375e+00,
#          1.24452783e+00, 1.12570356e-01],
#         [1.25078174e-02, 6.62914321e-02, 8.51782364e-01, 7.97998749e-01,
#          2.48905566e-01, 2.25140713e-02],
#         [1.87617261e-02, 9.94371482e-02, 1.27767355e+00, 1.19699812e+00,
#          3.73358349e-01, 3.37711069e-02],
#         [3.75234522e-02, 1.98874296e-01, 2.55534709e+00, 2.39399625e+00,
#          7.46716698e-01, 6.75422139e-02],
#         [3.75234522e-02, 1.98874296e-01, 2.55534709e+00, 2.39399625e+00,
#          7.46716698e-01, 6.75422139e-02],
#         [3.12695435e-02, 1.65728580e-01, 2.12945591e+00, 1.99499687e+00,
# ...

# %%
redwine_crosstab = pd.crosstab(redwine["citric acid"], redwine["quality"])

# %%
stats.chi2_contingency(redwine_crosstab)
# Out:
# (695.8184581409294,
#  6.425123780025564e-19,
#  395,
#  array([[8.25515947e-01, 4.37523452e+00, 5.62176360e+01, 5.26679174e+01,
#          1.64277674e+01, 1.48592871e+00],
#         [2.06378987e-01, 1.09380863e+00, 1.40544090e+01, 1.31669794e+01,
#          4.10694184e+00, 3.71482176e-01],
#         [3.12695435e-01, 1.65728580e+00, 2.12945591e+01, 1.99499687e+01,
#          6.22263915e+00, 5.62851782e-01],
#         [1.87617261e-01, 9.94371482e-01, 1.27767355e+01, 1.19699812e+01,
#          3.73358349e+00, 3.37711069e-01],
#         [1.81363352e-01, 9.61225766e-01, 1.23508443e+01, 1.15709819e+01,
#          3.60913071e+00, 3.26454034e-01],
#         [1.25078174e-01, 6.62914321e-01, 8.51782364e+00, 7.97998749e+00,
#          2.48905566e+00, 2.25140713e-01],
#         [1.50093809e-01, 7.95497186e-01, 1.02213884e+01, 9.57598499e+00,
#          2.98686679e+00, 2.70168856e-01],
#         [1.37585991e-01, 7.29205754e-01, 9.36960600e+00, 8.77798624e+00,
# ...

# %%
residual sugar	chlorides	free sulfur dioxide	total sulfur dioxide	density	pH	sulphates	alcohol	quality
# Out:
#   Input In [12]
#     residual sugar	chlorides	free sulfur dioxide	total sulfur dioxide	density	pH	sulphates	alcohol	quality
#              ^
# SyntaxError: invalid syntax

# %%
redwine_crosstab = pd.crosstab(redwine["alcohol"], redwine["quality"])

# %%
stats.chi2_contingency(redwine_crosstab)

# %%
redwine_crosstab = pd.crosstab(redwine["sulphates"], redwine["quality"])
stats.chi2_contingency(redwine_crosstab)

# %%
redwine_crosstab = pd.crosstab(redwine["pH"], redwine["quality"])
stats.chi2_contingency(redwine_crosstab)

# %%
redwine_crosstab = pd.crosstab(redwine["density"], redwine["quality"])
stats.chi2_contingency(redwine_crosstab)
